# %% [markdown]
# # problem 1.17 notes

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame({'T':[100,200,300,400,500,600], 'B':[-160, -35, -4.2, 9.0, 16.9, 21.3]})

# %%
df
# Out:
#      T      B
# 0  100 -160.0
# 1  200  -35.0
# 2  300   -4.2
# 3  400    9.0
# 4  500   16.9
# 5  600   21.3

# %%
df['B2'] = df['B']/100**3

# %%
df
# Out:
#      T      B        B2
# 0  100 -160.0 -0.000160
# 1  200  -35.0 -0.000035
# 2  300   -4.2 -0.000004
# 3  400    9.0  0.000009
# 4  500   16.9  0.000017
# 5  600   21.3  0.000021

# %%
df.iloc[2]
# Out:
# T     300.000000
# B      -4.200000
# B2     -0.000004
# Name: 2, dtype: float64

# %%
df.iloc[2].B2
# Out:
# np.float64(-4.2000000000000004e-06)

# %%
df['B2'].iloc[2]
# Out:
# np.float64(-4.2000000000000004e-06)

# %%
fig0, ax0 = plt.subplots()
ax0.plot(df['T'],df['B'], 'o')

# %%
df['T']
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# 5    600
# Name: T, dtype: int64

# %%
fig1, ax1 = plt.subplots()
ax1.plot(df['T'],df['B2'], 'o')
